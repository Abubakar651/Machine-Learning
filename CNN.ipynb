# %%
import tensorflow as tf
from tensorflow.keras import layers,models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
x_train=x_train[...,tf.newaxis].astype('float32')/255.0
x_test=x_test[...,tf.newaxis].astype('float32')/255.0

# %%
(_, y_train_raw), (_, y_test_raw) = mnist.load_data()

y_train = tf.keras.utils.to_categorical(y_train_raw, 10)
y_test = tf.keras.utils.to_categorical(y_test_raw, 10)

# %%
train_ds=tf.data.Dataset.from_tensor_slices((x_train,y_train))
train_ds=train_ds.shuffle(buffer_size=60000).batch(32).prefetch(tf.data.AUTOTUNE)

# %%
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_ds = test_ds.batch(32).prefetch(tf.data.AUTOTUNE)

# %%
model=models.Sequential([
  layers.Conv2D(32,(3,3),padding='same',activation='relu',input_shape=(28,28,1)),
  layers.MaxPooling2D(pool_size=(2,2),strides=2),

  layers.Conv2D(64,(3,3),padding='same',activation='relu'),
layers.MaxPooling2D(pool_size=(2,2),strides=2),

  layers.Flatten(),
layers.Dense(128,activation='relu'),
layers.Dropout(0.25),
layers.Dense(10,activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       401,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 421,642 (1.61 MB)
#  Trainable params: 421,642 (1.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']

)

# %%
history = model.fit(
    train_ds,
    epochs=20,
    validation_data=test_ds
)
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.9029 - loss: 0.3071 - val_accuracy: 0.9843 - val_loss: 0.0507
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 77s 41ms/step - accuracy: 0.9836 - loss: 0.0514 - val_accuracy: 0.9895 - val_loss: 0.0301
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 41ms/step - accuracy: 0.9892 - loss: 0.0342 - val_accuracy: 0.9898 - val_loss: 0.0314
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 40ms/step - accuracy: 0.9913 - loss: 0.0276 - val_accuracy: 0.9901 - val_loss: 0.0300
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 75s 40ms/step - accuracy: 0.9930 - loss: 0.0216 - val_accuracy: 0.9914 - val_loss: 0.0285
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 76s 40ms/step - accuracy: 0.9942 - loss: 0.0177 - val_accuracy: 0.9912 - val_loss: 0.0281
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 75s 40ms/step - accuracy: 0.9953 - loss: 0.0138 - val_accuracy: 0.9919 - val_loss: 0.0268
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 73s 39ms/step - accuracy: 0.9957 - loss: 0.0131 - val_accuracy: 0.9902 - val_loss: 0.0359
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 83s 40ms/step - accuracy: 0.9957 - loss: 0.0122 - val_accuracy: 0.9906 - val_loss: 0.0353
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 76s 40ms/step - accuracy: 0.9969 - loss: 0.0095 - val_accuracy: 0.9920 - val_loss: 0.0311
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 76s 41ms/step - accuracy: 0.9967 - loss: 0.0101 - val_accuracy: 0.9896 - val_loss: 0.0382
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 76s 41ms/step - accuracy: 0.9967 - loss: 0.0091 - val_accuracy: 0.9892 - val_loss: 0.0463
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 40ms/step - accuracy: 0.9972 - loss: 0.0079 - val_accuracy: 0.9925 - val_loss: 0.0318
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 75s 40ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9918 - val_loss: 0.0381
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 75s 40ms/step - accuracy: 0.9974 - loss: 0.0067 - val_accuracy: 0.9913 - val_loss: 0.0388
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 75s 40ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9919 - val_loss: 0.0368
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 83s 41ms/step - accuracy: 0.9978 - loss: 0.0063 - val_accuracy: 0.9923 - val_loss: 0.0381
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 83s 41ms/step - accuracy: 0.9976 - loss: 0.0063 - val_accuracy: 0.9920 - val_loss: 0.0361
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 41ms/step - accuracy: 0.9985 - loss: 0.0044 - val_accuracy: 0.9918 - val_loss: 0.0383
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 85s 43ms/step - accuracy: 0.9977 - loss: 0.0073 - val_accuracy: 0.9912 - val_loss: 0.0439

# %%
test_loss, test_accuracy = model.evaluate(test_ds)
print(f"Test Accuracy: {test_accuracy*100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9877 - loss: 0.0584
# Test Accuracy: 99.12%
